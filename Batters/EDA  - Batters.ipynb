# %% [markdown]
# ## Importing required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Cleaning & Preprocessing

# %%
bat = pd.read_csv("Batting Records.csv")
bat
# Out:
#                   name country       span  matches innings not_out  runs  \
# 0              V Kohli     IND  2010-2022      115     107      31  4008
# 1            RG Sharma     IND  2007-2022      148     140      17  3853
# 2           MJ Guptill      NZ  2009-2022      122     118       7  3531
# 3           Babar Azam     PAK  2016-2023      104      98      14  3485
# 4          PR Stirling     IRE  2009-2023      131     130      11  3408
# ...                ...     ...        ...      ...     ...     ...   ...
# 3495     Shabbir Ahmed     PAK  2007-2007        1       -       -     -
# 3496  Shaffeq Muhammad     GRC  2019-2019        2       -       -     -
# 3497    Shohidul Islam     BAN  2021-2021        1       -       -     -
# 3498  Sharif Asadullah     UAE  2014-2014        1       -       -     -
# 3499         KV Sharma     IND  2014-2014        1       -       -     -
#
#      highest_score average balls_faced strike_rate 100s 50s duck   4s   6s
# ...

# %%
bat.drop(bat[bat['innings']=="-"].index,inplace=True)
bat.drop(bat[bat['average']=="-"].index,inplace=True)
bat.drop(bat[bat['strike_rate']=="-"].index,inplace=True)
bat
# Out:
#                  name country       span  matches innings not_out  runs  \
# 0             V Kohli     IND  2010-2022      115     107      31  4008
# 1           RG Sharma     IND  2007-2022      148     140      17  3853
# 2          MJ Guptill      NZ  2009-2022      122     118       7  3531
# 3          Babar Azam     PAK  2016-2023      104      98      14  3485
# 4         PR Stirling     IRE  2009-2023      131     130      11  3408
# ...               ...     ...        ...      ...     ...     ...   ...
# 3306     Waqar Abbasi     ROM  2020-2021        3       1       0     0
# 3307  Zabiullah Zahid     SWE  2023-2023        1       1       0     0
# 3308     Zafer Durmaz     TKY  2022-2022        2       2       0     0
# 3309      Zhao Tianle     CHN  2023-2023        2       2       0     0
# 3310        M Zondeki      SA  2006-2006        1       1       0     0
#
#      highest_score average balls_faced strike_rate 100s 50s duck   4s   6s
# ...

# %%
bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3046 entries, 0 to 3310
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           3046 non-null   object
#  1   country        3046 non-null   object
#  2   span           3046 non-null   object
#  3   matches        3046 non-null   int64
#  4   innings        3046 non-null   object
#  5   not_out        3046 non-null   object
#  6   runs           3046 non-null   object
#  7   highest_score  3046 non-null   object
#  8   average        3046 non-null   object
#  9   balls_faced    3046 non-null   object
#  10  strike_rate    3046 non-null   object
#  11  100s           3046 non-null   object
#  12  50s            3046 non-null   object
#  13  duck           3046 non-null   object
#  14  4s             3046 non-null   object
#  15  6s             3046 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 404.5+ KB

# %%
bat['innings'] = bat['innings'].astype('int64')
bat['not_out'] = bat['not_out'].astype('int64')
bat['runs'] = bat['runs'].astype('int64')
bat['average'] = bat['average'].astype('float64')
bat['balls_faced'] = bat['balls_faced'].astype('int64')
bat['strike_rate'] = bat['strike_rate'].astype('float64')
bat['100s'] = bat['100s'].astype('int64')
bat['50s'] = bat['50s'].astype('int64')
bat['duck'] = bat['duck'].astype('int64')
bat['4s'] = bat['4s'].astype('int64')
bat['6s'] = bat['6s'].astype('int64')

# %%
bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3046 entries, 0 to 3310
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           3046 non-null   object
#  1   country        3046 non-null   object
#  2   span           3046 non-null   object
#  3   matches        3046 non-null   int64
#  4   innings        3046 non-null   int64
#  5   not_out        3046 non-null   int64
#  6   runs           3046 non-null   int64
#  7   highest_score  3046 non-null   object
#  8   average        3046 non-null   float64
#  9   balls_faced    3046 non-null   int64
#  10  strike_rate    3046 non-null   float64
#  11  100s           3046 non-null   int64
#  12  50s            3046 non-null   int64
#  13  duck           3046 non-null   int64
#  14  4s             3046 non-null   int64
#  15  6s             3046 non-null   int64
# dtypes: float64(2), int64(10), object(4)
# memory usage: 404.5+ KB

# %%
bat.duplicated().sum()
# Out:
# 0

# %%
bat.dropna(axis=0,inplace=True)

# %%
bat.loc[bat.innings == bat.not_out].count()
# Out:
# name             0
# country          0
# span             0
# matches          0
# innings          0
# not_out          0
# runs             0
# highest_score    0
# average          0
# balls_faced      0
# strike_rate      0
# 100s             0
# 50s              0
# duck             0
# 4s               0
# 6s               0
# dtype: int64

# %%
bat[(bat.runs<400) & (bat.country == "IND")]
# Out:
#                 name country       span  matches  innings  not_out  runs  \
# 395         V Sehwag     IND  2006-2012       19       18        0   394
# 416        AM Rahane     IND  2011-2016       20       20        2   375
# 417        SV Samson     IND  2015-2023       24       21        2   374
# 423         DJ Hooda     IND  2022-2023       21       17        5   368
# 468         AR Patel     IND  2015-2023       45       28       12   328
# ...              ...     ...        ...      ...      ...      ...   ...
# 3191       PP Chawla     IND  2010-2012        7        1        0     0
# 3250  Mohammed Shami     IND  2014-2022       23        3        2     0
# 3270        MM Patel     IND  2011-2011        3        1        0     0
# 3288         PP Shaw     IND  2021-2021        1        1        0     0
# 3302        CV Varun     IND  2021-2021        6        1        0     0
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck  4s  6s
# ...

# %%
highest_scores = bat.loc[bat.innings == bat.not_out]['highest_score'].tolist()
highest_scores = [ x[:-1] for x in highest_scores ]
highest_scores = [ int(x) for x in highest_scores ]

highest_scores
# Out:
# []

# %%
bat.country.unique()
# Out:
# array(['IND', 'NZ', 'PAK', 'IRE', 'AUS', 'ENG', 'ICC/PAK', 'BAN', 'SA',
#        'SA/World', 'SCOT', 'AFG', 'WI', 'SL', 'MAL', 'BAN/ICC/World',
#        'UGA', 'ZIM', 'NED', 'PNG', 'KENYA', 'HKG/NZ', 'UAE', 'TAN',
#        'ICC/SL/World', 'ROM', 'CZK-R', 'HKG', 'KUW', 'NEP', 'MLT', 'OMA',
#        'Aut', 'NAM', 'QAT', 'RWN', 'JER', 'BOT', 'BHR', 'BUL', 'GIBR',
#        'MOZ', 'AUS/SGP', 'VAN', 'SGP', 'CAN', 'DEN', 'MWI', 'SUI', 'LUX',
#        'Belg', 'ICC/IND', 'BMUDA', 'SRB', 'Fran', 'Fin', 'ESP', 'GUE',
#        'WI/World', 'ENG/World', 'GER', 'USA', 'HUN', 'NGA', 'KSA', 'JPN',
#        'Ghana', 'ENG/ICC', 'AUS/World', 'NOR', 'NED/SA', 'NAM/SA', 'MDV',
#        'PORT', '3', 'Bhm', 'ENG/IRE', 'ITA', 'IOM', 'Arg', 'AFG/ICC',
#        'AUS/ICC/NZ', 'Fiji', 'PHI', 'USA/WI', 'COK', 'SWE', 'EST', 'SLE',
#        'Samoa', 'SEY', 'SWZ', 'CAM', 'Caym', 'NED/NZ', 'CYP', 'LES',
#        'BHU', 'SWA/SWZ', 'PNM', 'Blz', 'NZ/World', 'INA', 'THAI', 'Mex',
# ...

# %%
bat.loc[bat['country'] == 'ICC/SL/World']
# Out:
#            name       country       span  matches  innings  not_out  runs  \
# 87  NLTC Perera  ICC/SL/World  2010-2021       84       74       22  1204
#
#    highest_score  average  balls_faced  strike_rate  100s  50s  duck  4s  6s
# 87            61    23.15          794       151.63     0    3     8  88  64

# %%
bat.country.str.isnumeric().sum()
# Out:
# 5

# %%
bat[bat["country"].isin(['1','2','3'])]
# Out:
#                 name country       span  matches  innings  not_out  runs  \
# 368   Mohammad Nawaz       3  2016-2023       57       35       11   427
# 1661  Mohammad Wasim       1  2021-2023       27       10        6    45
# 2060     Rameez Raja       2  2011-2011        2        2        0    24
# 2307     Aftab Ahmed       2  2019-2021        4        3        0    15
# 3220      Imran Khan       1  2015-2015        3        1        0     0
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck  4s  6s
# 368            45*    17.79          327       130.58     0    0     4  36  19
# 1661           12*    11.25           50        90.00     0    0     1   5   1
# 2060            23    12.00           29        82.75     0    0     0   2   0
# 2307            10     5.00           27        55.55     0    0     0   1   0
# 3220             0     0.00            1         0.00     0    0     1   0   0

# %%
bat.loc[(bat.name=="Aftab Ahmed"),'country'] = "BAN"
bat[bat["country"].isin(['1','2','3'])]
# Out:
#                 name country       span  matches  innings  not_out  runs  \
# 368   Mohammad Nawaz       3  2016-2023       57       35       11   427
# 1661  Mohammad Wasim       1  2021-2023       27       10        6    45
# 2060     Rameez Raja       2  2011-2011        2        2        0    24
# 3220      Imran Khan       1  2015-2015        3        1        0     0
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck  4s  6s
# 368            45*    17.79          327       130.58     0    0     4  36  19
# 1661           12*    11.25           50        90.00     0    0     1   5   1
# 2060            23    12.00           29        82.75     0    0     0   2   0
# 3220             0     0.00            1         0.00     0    0     1   0   0

# %%
bat.loc[(bat.country.str.isnumeric()),'country'] = "PAK"
bat[bat["country"].isin(['1','2','3'])]
# Out:
# Empty DataFrame
# Columns: [name, country, span, matches, innings, not_out, runs, highest_score, average, balls_faced, strike_rate, 100s, 50s, duck, 4s, 6s]
# Index: []

# %%
bat.nunique(axis=0)
# Out:
# name             3027
# country           128
# span              177
# matches           108
# innings            98
# not_out            33
# runs              668
# highest_score     244
# average          1091
# balls_faced       619
# strike_rate      1777
# 100s                5
# 50s                27
# duck               14
# 4s                166
# 6s                 96
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.boxplot(bat.runs)
plt.title("Runs")
# Out:
# Text(0.5, 1.0, 'Runs')

# %%
sns.boxplot(bat.strike_rate)
plt.title("Strike Rate")
# Out:
# Text(0.5, 1.0, 'Strike Rate')

# %%
sns.boxplot(bat.average)
plt.title("Average")
# Out:
# Text(0.5, 1.0, 'Average')

# %%
bat[['matches','innings']].plot(kind='box')
plt.title("Matches & Innings")
# Out:
# Text(0.5, 1.0, 'Matches & Innings')

# %%
# Dropping Players who have played 4 innings or less
bat.drop(bat[(bat.innings <= 3) | (bat.balls_faced < 25)].index, inplace=True)

# %%
bat['country'] = bat['country'].str.replace(r'/World','',regex=True)
bat['country'] = bat['country'].str.replace(r'/ICC','',regex=True)
bat['country'] = bat['country'].str.replace(r'ICC/','',regex=True)

# %%
bat.country.unique()
# Out:
# array(['IND', 'NZ', 'PAK', 'IRE', 'AUS', 'ENG', 'BAN', 'SA', 'SCOT',
#        'AFG', 'WI', 'SL', 'MAL', 'UGA', 'ZIM', 'NED', 'PNG', 'KENYA',
#        'HKG/NZ', 'UAE', 'TAN', 'ROM', 'CZK-R', 'HKG', 'KUW', 'NEP', 'MLT',
#        'OMA', 'Aut', 'NAM', 'QAT', 'RWN', 'JER', 'BOT', 'BHR', 'BUL',
#        'GIBR', 'MOZ', 'AUS/SGP', 'VAN', 'SGP', 'CAN', 'DEN', 'MWI', 'SUI',
#        'LUX', 'Belg', 'BMUDA', 'SRB', 'Fran', 'Fin', 'ESP', 'GUE', 'GER',
#        'USA', 'HUN', 'NGA', 'KSA', 'JPN', 'Ghana', 'NOR', 'NED/SA',
#        'NAM/SA', 'MDV', 'PORT', 'Bhm', 'ENG/IRE', 'ITA', 'IOM', 'Arg',
#        'AUS/NZ', 'Fiji', 'PHI', 'USA/WI', 'COK', 'SWE', 'EST', 'SLE',
#        'Samoa', 'SEY', 'SWZ', 'CAM', 'Caym', 'NED/NZ', 'CYP', 'LES',
#        'BHU', 'SWA/SWZ', 'PNM', 'Blz', 'INA', 'THAI', 'Mex', 'GRC',
#        'GAMBI', 'TKY', 'STHEL', 'CRT', 'ISR', 'SVN', 'SWA', 'Peru',
#        'Chile', 'SKOR', 'MWI/ZIM', 'BRA', 'Mali', 'DEN/ENG', 'MYAN',
#        'CHN', 'ENG/ITA'], dtype=object)

# %%
# Top 10 Countries by ICC Rankings
top10countries = ['INDIA','ENG','PAK','SA','NZ','AUS','WI','SL','BAN','AFG']

# %%
bat[bat.country.isin(top10countries)].sort_values('100s',ascending=False)
# Out:
#                name country       span  matches  innings  not_out  runs  \
# 3        Babar Azam     PAK  2016-2023      104       98       14  3485
# 35          C Munro      NZ  2012-2020       65       62        7  1724
# 17       GJ Maxwell     AUS  2012-2022       98       90       14  2159
# 2        MJ Guptill      NZ  2009-2022      122      118        7  3531
# 62          E Lewis      WI  2016-2022       53       52        3  1465
# ...             ...     ...        ...      ...      ...      ...   ...
# 396    Abdul Razzaq     PAK  2006-2013       32       29       10   393
# 393   Hussain Talat     PAK  2018-2021       18       18        2   394
# 390     Shan Masood     PAK  2022-2022       19       17        4   395
# 388        HH Gibbs      SA  2005-2010       23       23        1   400
# 2587       T Shamsi      SA  2017-2023       63       13        8     9
#
#      highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s  \
# ...

# %% [markdown]
# ## KPI Extraction

# %% [markdown]
# plt.figure(figsize=(50,25))
# sns.countplot(bat.country)
# plt.xticks(rotation=45)
# plt.show()

# %% [markdown]
# bat_country = bat.groupby('country').count()
# min_bat_countries = bat_country[bat_country.name>15].index

# %% [markdown]
# plt.figure(figsize=(30,15))
# sns.countplot(x="country",data = bat[bat['country'].isin(min_bat_countries)])
# plt.xticks(rotation=45)
# plt.show()

# %%
boundaries = bat["4s"] + bat["6s"]
bat['boundary_per_ball'] = np.round(boundaries/bat['balls_faced'],3)
bat.head()
# Out:
#           name country       span  matches  innings  not_out  runs  \
# 0      V Kohli     IND  2010-2022      115      107       31  4008
# 1    RG Sharma     IND  2007-2022      148      140       17  3853
# 2   MJ Guptill      NZ  2009-2022      122      118        7  3531
# 3   Babar Azam     PAK  2016-2023      104       98       14  3485
# 4  PR Stirling     IRE  2009-2023      131      130       11  3408
#
#   highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s   6s  \
# 0          122*    52.73         2905       137.96     1   37     4  356  117
# 1           118    31.32         2767       139.24     4   29    10  348  182
# 2           105    31.81         2602       135.70     2   20     3  309  173
# 3           122    41.48         2714       128.40     3   30     5  371   53
# 4          115*    28.63         2509       135.83     1   23    13  394  123
#
#    boundary_per_ball
# 0              0.163
# 1              0.192
# 2              0.185
# ...

# %%
sns.boxplot(bat.boundary_per_ball)
plt.title("Boundaries per Ball")
# Out:
# Text(0.5, 1.0, 'Boundaries per Ball')

# %%
bat['boundary_index'] = np.round(boundaries/bat.innings,3)
bat.head()
# Out:
#           name country       span  matches  innings  not_out  runs  \
# 0      V Kohli     IND  2010-2022      115      107       31  4008
# 1    RG Sharma     IND  2007-2022      148      140       17  3853
# 2   MJ Guptill      NZ  2009-2022      122      118        7  3531
# 3   Babar Azam     PAK  2016-2023      104       98       14  3485
# 4  PR Stirling     IRE  2009-2023      131      130       11  3408
#
#   highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s   6s  \
# 0          122*    52.73         2905       137.96     1   37     4  356  117
# 1           118    31.32         2767       139.24     4   29    10  348  182
# 2           105    31.81         2602       135.70     2   20     3  309  173
# 3           122    41.48         2714       128.40     3   30     5  371   53
# 4          115*    28.63         2509       135.83     1   23    13  394  123
#
#    boundary_per_ball  boundary_index
# 0              0.163           4.421
# ...

# %%
sns.boxplot(bat.boundary_index)
plt.title("Boundaries index")
# Out:
# Text(0.5, 1.0, 'Boundaries index')

# %%
bat['not_out_pct'] = np.round(bat['not_out']/bat.innings,3)
bat.head()
# Out:
#           name country       span  matches  innings  not_out  runs  \
# 0      V Kohli     IND  2010-2022      115      107       31  4008
# 1    RG Sharma     IND  2007-2022      148      140       17  3853
# 2   MJ Guptill      NZ  2009-2022      122      118        7  3531
# 3   Babar Azam     PAK  2016-2023      104       98       14  3485
# 4  PR Stirling     IRE  2009-2023      131      130       11  3408
#
#   highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s   6s  \
# 0          122*    52.73         2905       137.96     1   37     4  356  117
# 1           118    31.32         2767       139.24     4   29    10  348  182
# 2           105    31.81         2602       135.70     2   20     3  309  173
# 3           122    41.48         2714       128.40     3   30     5  371   53
# 4          115*    28.63         2509       135.83     1   23    13  394  123
#
#    boundary_per_ball  boundary_index  not_out_pct
# ...

# %%
sns.boxplot(bat.not_out_pct)
plt.title("Not out%")
# Out:
# Text(0.5, 1.0, 'Not out%')

# %%
bat['duck_index'] = np.round(bat['duck']/bat.innings,3)
bat.head()
# Out:
#           name country       span  matches  innings  not_out  runs  \
# 0      V Kohli     IND  2010-2022      115      107       31  4008
# 1    RG Sharma     IND  2007-2022      148      140       17  3853
# 2   MJ Guptill      NZ  2009-2022      122      118        7  3531
# 3   Babar Azam     PAK  2016-2023      104       98       14  3485
# 4  PR Stirling     IRE  2009-2023      131      130       11  3408
#
#   highest_score  average  balls_faced  strike_rate  100s  50s  duck   4s   6s  \
# 0          122*    52.73         2905       137.96     1   37     4  356  117
# 1           118    31.32         2767       139.24     4   29    10  348  182
# 2           105    31.81         2602       135.70     2   20     3  309  173
# 3           122    41.48         2714       128.40     3   30     5  371   53
# 4          115*    28.63         2509       135.83     1   23    13  394  123
#
#    boundary_per_ball  boundary_index  not_out_pct  duck_index
# ...

# %%
sns.boxplot(bat.duck_index)
plt.title("Duck index")
# Out:
# Text(0.5, 1.0, 'Duck index')

# %%
rwob = bat.runs - 4*bat['4s'] - 6*bat['6s']
bat['RwoB_index'] = np.round(rwob/bat.innings,3)
bat.head()
# Out:
#           name country       span  matches  innings  not_out  runs  \
# 0      V Kohli     IND  2010-2022      115      107       31  4008
# 1    RG Sharma     IND  2007-2022      148      140       17  3853
# 2   MJ Guptill      NZ  2009-2022      122      118        7  3531
# 3   Babar Azam     PAK  2016-2023      104       98       14  3485
# 4  PR Stirling     IRE  2009-2023      131      130       11  3408
#
#   highest_score  average  balls_faced  ...  100s  50s  duck   4s   6s  \
# 0          122*    52.73         2905  ...     1   37     4  356  117
# 1           118    31.32         2767  ...     4   29    10  348  182
# 2           105    31.81         2602  ...     2   20     3  309  173
# 3           122    41.48         2714  ...     3   30     5  371   53
# 4          115*    28.63         2509  ...     1   23    13  394  123
#
#    boundary_per_ball  boundary_index  not_out_pct  duck_index  RwoB_index
# ...

# %%
sns.boxplot(bat.RwoB_index)
plt.title("Runs without Boundaries Index")
# Out:
# Text(0.5, 1.0, 'Runs without Boundaries Index')

# %%
bat['big_match_index'] = np.round(((2 * bat['100s']) + bat['50s']) / bat.innings,3)
bat.head()
# Out:
#           name country       span  matches  innings  not_out  runs  \
# 0      V Kohli     IND  2010-2022      115      107       31  4008
# 1    RG Sharma     IND  2007-2022      148      140       17  3853
# 2   MJ Guptill      NZ  2009-2022      122      118        7  3531
# 3   Babar Azam     PAK  2016-2023      104       98       14  3485
# 4  PR Stirling     IRE  2009-2023      131      130       11  3408
#
#   highest_score  average  balls_faced  ...  50s  duck   4s   6s  \
# 0          122*    52.73         2905  ...   37     4  356  117
# 1           118    31.32         2767  ...   29    10  348  182
# 2           105    31.81         2602  ...   20     3  309  173
# 3           122    41.48         2714  ...   30     5  371   53
# 4          115*    28.63         2509  ...   23    13  394  123
#
#    boundary_per_ball  boundary_index  not_out_pct  duck_index  RwoB_index  \
# 0              0.163           4.421        0.290       0.037      17.589
# ...

# %%
sns.boxplot(bat.big_match_index)
plt.title("Big Match Index")
# Out:
# Text(0.5, 1.0, 'Big Match Index')

# %% [markdown]
# ## Clustering Dataset

# %%
batter = bat[['name','country','average','strike_rate','boundary_per_ball','boundary_index','not_out_pct','duck_index','RwoB_index','big_match_index']]
batter.head()
# Out:
#           name country  average  strike_rate  boundary_per_ball  \
# 0      V Kohli     IND    52.73       137.96              0.163
# 1    RG Sharma     IND    31.32       139.24              0.192
# 2   MJ Guptill      NZ    31.81       135.70              0.185
# 3   Babar Azam     PAK    41.48       128.40              0.156
# 4  PR Stirling     IRE    28.63       135.83              0.206
#
#    boundary_index  not_out_pct  duck_index  RwoB_index  big_match_index
# 0           4.421        0.290       0.037      17.589            0.364
# 1           3.786        0.121       0.071       9.779            0.264
# 2           4.085        0.059       0.025      10.653            0.203
# 3           4.327        0.143       0.051      17.173            0.367
# 4           3.977        0.085       0.100       8.415            0.192

# %%
batter.describe()
# Out:
#            average  strike_rate  boundary_per_ball  boundary_index  \
# count  1923.000000  1923.000000        1923.000000     1923.000000
# mean     17.693630   105.952652           0.119725        1.612155
# std       9.634947    28.825118           0.057469        1.147454
# min       0.750000    10.340000           0.000000        0.000000
# 25%      10.660000    87.745000           0.080500        0.750000
# 50%      16.280000   107.940000           0.120000        1.389000
# 75%      22.900000   125.275000           0.156000        2.270000
# max      72.500000   213.510000           0.324000        9.286000
#
#        not_out_pct   duck_index   RwoB_index  big_match_index
# count  1923.000000  1923.000000  1923.000000      1923.000000
# mean      0.206111     0.107893     6.529303         0.048956
# std       0.182603     0.112549     3.290244         0.085972
# min       0.000000     0.000000     0.400000         0.000000
# ...

# %%
cluster_bat = batter.copy().drop(['name','country'],axis=1)
cluster_bat
# Out:
#       average  strike_rate  boundary_per_ball  boundary_index  not_out_pct  \
# 0       52.73       137.96              0.163           4.421        0.290
# 1       31.32       139.24              0.192           3.786        0.121
# 2       31.81       135.70              0.185           4.085        0.059
# 3       41.48       128.40              0.156           4.327        0.143
# 4       28.63       135.83              0.206           3.977        0.085
# ...       ...          ...                ...             ...          ...
# 2587     1.80        34.61              0.000           0.000        0.615
# 2600     1.14        23.52              0.000           0.000        0.125
# 2642     2.00        22.22              0.000           0.000        0.000
# 2755     2.50        20.00              0.000           0.000        0.500
# 2913     0.75        10.34              0.000           0.000        0.000
#
#       duck_index  RwoB_index  big_match_index
# ...

# %% [markdown]
# ## Preliminary Rank Metrics

# %%
bat['prelim'] = np.round((bat.average*bat.strike_rate)/100,3)
bat.head()
# Out:
#           name country       span  matches  innings  not_out  runs  \
# 0      V Kohli     IND  2010-2022      115      107       31  4008
# 1    RG Sharma     IND  2007-2022      148      140       17  3853
# 2   MJ Guptill      NZ  2009-2022      122      118        7  3531
# 3   Babar Azam     PAK  2016-2023      104       98       14  3485
# 4  PR Stirling     IRE  2009-2023      131      130       11  3408
#
#   highest_score  average  balls_faced  ...  duck   4s   6s  boundary_per_ball  \
# 0          122*    52.73         2905  ...     4  356  117              0.163
# 1           118    31.32         2767  ...    10  348  182              0.192
# 2           105    31.81         2602  ...     3  309  173              0.185
# 3           122    41.48         2714  ...     5  371   53              0.156
# 4          115*    28.63         2509  ...    13  394  123              0.206
#
#    boundary_index  not_out_pct  duck_index  RwoB_index  big_match_index  \
# ...

# %%
bat.describe()
# Out:
#            matches      innings      not_out         runs      average  \
# count  1923.000000  1923.000000  1923.000000  1923.000000  1923.000000
# mean     21.796152    17.186167     3.410296   289.669787    17.693630
# std      20.231723    17.285738     4.149475   430.991465     9.634947
# min       4.000000     4.000000     0.000000     3.000000     0.750000
# 25%       8.000000     6.000000     1.000000    58.000000    10.660000
# 50%      15.000000    11.000000     2.000000   128.000000    16.280000
# 75%      28.000000    21.000000     5.000000   323.000000    22.900000
# max     148.000000   140.000000    42.000000  4008.000000    72.500000
#
#        balls_faced  strike_rate         100s          50s         duck  \
# count  1923.000000  1923.000000  1923.000000  1923.000000  1923.000000
# mean    244.276651   105.952652     0.063963     1.202808     1.593864
# std     326.905599    28.825118     0.310359     2.849403     1.743698
# ...

# %%
sns.boxplot(bat.prelim)
# Out:
# <Axes: >

# %% [markdown]
# Ranking using Prelim Metric

# %%
bat.loc[((bat.prelim>30) & (bat.runs>=500)),'prelim_rank'] = "Best"
bat.loc[((bat.prelim>30) & (bat.runs<500)),'prelim_rank'] = "Good"
bat.loc[((bat.prelim>20) & (bat.prelim<=30)),'prelim_rank'] = "Good"
bat.loc[((bat.prelim>=10) & (bat.prelim<=20)),'prelim_rank'] = "Average"
bat.loc[((bat.prelim<10)),'prelim_rank'] = "Poor"
bat.loc[((bat.runs<100)),'prelim_rank'] = "Poor"

# %%
bat
# Out:
#              name country       span  matches  innings  not_out  runs  \
# 0         V Kohli     IND  2010-2022      115      107       31  4008
# 1       RG Sharma     IND  2007-2022      148      140       17  3853
# 2      MJ Guptill      NZ  2009-2022      122      118        7  3531
# 3      Babar Azam     PAK  2016-2023      104       98       14  3485
# 4     PR Stirling     IRE  2009-2023      131      130       11  3408
# ...           ...     ...        ...      ...      ...      ...   ...
# 2587     T Shamsi      SA  2017-2023       63       13        8     9
# 2600     AR Balla     CAM  2021-2022        8        8        1     8
# 2642   Xie Kunkun     CHN  2023-2023        4        4        0     8
# 2755      P Bhart     NOR  2019-2021       10        4        2     5
# 2913     Khin Aye    MYAN  2023-2023        4        4        0     3
#
#      highest_score  average  balls_faced  ...   4s   6s  boundary_per_ball  \
# ...

# %%
sns.countplot(bat.prelim_rank)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 sns.countplot(bat.prelim_rank)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
bat.prelim_rank.value_counts()

# %%
batter["prelim_metric"] = bat["prelim"]
batter["prelim_rank"] = bat["prelim_rank"]
batter.head()

# %%
bat_test = batter.sample(frac=0.07,random_state=25)
bat_test.shape

# %%
bat_train = batter.drop(bat_test.index)
bat_train.shape

# %%
batter

# %%
batter.to_csv("Batting Cluster Dataset.csv",index=False)
bat_train.to_csv("Training Batters.csv",index=False)
bat_test.to_csv("Test Batters.csv",index=False)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn import metrics
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering

# %%
col = cluster_bat.columns.tolist()
col

# %% [markdown]
# #### Normal Data

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data = cluster_bat)
plt.show()

# %%
cluster_bat.describe()

# %%
fig = plt.figure(figsize=(25,15))
ax = fig.gca()
cluster_bat.hist(ax = ax)
plt.show()

# %%
sns.heatmap(cluster_bat.corr(),annot=True)

# %%
wcss = []
for i in range(2,11):
    model = KMeans(i).fit(cluster_bat.dropna())
    wcss.append(model.inertia_)
plt.plot(np.arange(2,11,1),wcss)

# %%
for cl in range(2,11):
    cluster = KMeans(n_clusters = cl,random_state=10)
    cluster_labels = cluster.fit_predict(cluster_bat)
    
    avg_sil = silhouette_score(cluster_bat,cluster_labels)
    print("For n_clusters = {}, The Average Silhouette Score is {}".format(cl,avg_sil))

# %% [markdown]
# #### StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
std = scaler.fit_transform(cluster_bat)
std_bat = pd.DataFrame(std,columns=col)
std_bat.head()

# %%
std_bat.describe()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data = std_bat)
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
ax = fig.gca()
std_bat.hist(ax = ax)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(std_bat.corr(),annot=True)
plt.show()

# %%
wcss = []
for i in range(2,11):
    model = KMeans(i).fit(std_bat.dropna())
    wcss.append(model.inertia_)
plt.plot(np.arange(2,11,1),wcss)

# %%
for cl in range(2,11):
    cluster = KMeans(n_clusters = cl,random_state=10)
    cluster_labels = cluster.fit_predict(std_bat)
    
    avg_sil = silhouette_score(std_bat,cluster_labels)
    print("For n_clusters = {}, The Average Silhouette Score is {}".format(cl,avg_sil))

# %% [markdown]
# #### MinMax Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
mm = scaler.fit_transform(cluster_bat)
mm_bat = pd.DataFrame(mm,columns=col)
mm_bat.head()

# %%
mm_bat.describe()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data = mm_bat)
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
ax = fig.gca()
mm_bat.hist(ax = ax)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(mm_bat.corr(),annot=True)
plt.show()

# %%
wcss = []
for i in range(2,11):
    model = KMeans(i).fit(mm_bat.dropna())
    wcss.append(model.inertia_)
plt.plot(np.arange(2,11,1),wcss)

# %%
for cl in range(2,11):
    cluster = KMeans(n_clusters = cl,random_state=10)
    cluster_labels = cluster.fit_predict(mm_bat)
    
    avg_sil = silhouette_score(mm_bat,cluster_labels)
    print("For n_clusters = {}, The Average Silhouette Score is {}".format(cl,avg_sil))

# %% [markdown]
# #### Normalization

# %%
from sklearn.preprocessing import Normalizer

# %%
scaler = Normalizer()

# %%
norm = scaler.fit_transform(cluster_bat)
norm_bat = pd.DataFrame(norm,columns=col)
norm_bat.head()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data = norm_bat)
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
ax = fig.gca()
norm_bat.hist(ax = ax)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(norm_bat.corr(),annot=True)
plt.show()

# %%
wcss = []
for i in range(2,11):
    model = KMeans(i).fit(norm_bat.dropna())
    wcss.append(model.inertia_)
plt.plot(np.arange(2,11,1),wcss)

# %%
for cl in range(2,11):
    cluster = KMeans(n_clusters = cl,random_state=10)
    cluster_labels = cluster.fit_predict(norm_bat)
    
    avg_sil = silhouette_score(norm_bat,cluster_labels)
    print("For n_clusters = {}, The Average Silhouette Score is {}".format(cl,avg_sil))

# %% [markdown]
# #### Robust Scaling

# %%
from sklearn.preprocessing import RobustScaler

# %%
scaler = RobustScaler()

# %%
rb = scaler.fit_transform(cluster_bat)
rb_bat = pd.DataFrame(rb,columns=col)
rb_bat.head()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data = rb_bat)
plt.show()

# %%
fig = plt.figure(figsize=(25,15))
ax = fig.gca()
rb_bat.hist(ax = ax)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(rb_bat.corr(),annot=True)
plt.show()

# %%
wcss = []
for i in range(2,11):
    model = KMeans(i).fit(rb_bat.dropna())
    wcss.append(model.inertia_)
plt.plot(np.arange(2,11,1),wcss)

# %%
for cl in range(2,11):
    cluster = KMeans(n_clusters = cl,random_state=10)
    cluster_labels = cluster.fit_predict(rb_bat)
    
    avg_sil = silhouette_score(rb_bat,cluster_labels)
    print("For n_clusters = {}, The Average Silhouette Score is {}".format(cl,avg_sil))

# %% [markdown]
# <b> Out of the above performed Scaleings, Normalizer has produced better clustering results with an expected silhouette score of 0.5.
#     Therefore, we choose to proceed with Normalized Data </b>
